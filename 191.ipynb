# %%
num = 7
z = bin(num)[2:]
print(list(z))
list(z).count("1")
# Out:
# ['1', '1', '1']
# 3

# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        return list(bin(n)[2:]).count('1')
