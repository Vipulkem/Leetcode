# %%
con = ['b','c','d','f','g','h','j','k','l','m','n','p','q','r','s','t','v','w','x','y','z']

# %%
con = con + [i.upper() for i in con]

# %%
con
# Out:
# ['b',
#  'c',
#  'd',
#  'f',
#  'g',
#  'h',
#  'j',
#  'k',
#  'l',
#  'm',
#  'n',
#  'p',
#  'q',
#  'r',
#  's',
#  't',
#  'v',
#  'w',
#  'x',
#  'y',
#  'z',
#  'B',
#  'C',
#  'D',
#  'F',
#  'G',
#  'H',
#  'J',
#  'K',
#  'L',
#  'M',
#  'N',
#  'P',
#  'Q',
#  'R',
#  'S',
#  'T',
#  'V',
#  'W',
#  'X',
#  'Y',
#  'Z']

# %%
s = "nvesroil"
v = list(s)
v
# Out:
# ['n', 'v', 'e', 's', 'r', 'o', 'i', 'l']
