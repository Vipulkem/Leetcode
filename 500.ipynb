# %%
words = ["Hello","Alaska","Dad","Peace"]
l1 = list("qwertyuiop") + list("qwertyuiop".upper())
l2 = list("asdfghjkl") + list("asdfghjkl".upper())
l3 = list("zxcvbnm") + list("zxcvbnm".upper())
lis = []
for i in words:
    if set(i) <= set(l1):
        lis = lis + [i]
    elif set(i) <= set(l2):
        lis = lis + [i]
    elif set(i) <= set(l3):
        lis = lis + [i]
lis
# Out:
# ['Alaska', 'Dad']
