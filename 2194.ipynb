# %%
s = "K1:L2"

start_col = s[0]
end_col = s[3]
start_row = int(s[1])
end_row = int(s[4])

res = []

for col in range(ord(start_col),ord(end_col)+1):
    for row in range(start_row,end_row+1):
        res.append(f"{chr(col)}{row}")

print(res)
# Out:
# ['K1', 'K2', 'L1', 'L2']

# %%
class Solution:
    def cellsInRange(self, s: str) -> List[str]:
        res = []
        for col in range(ord(s[0]),ord(s[3])+1):
            for row in range(int(s[1]),int(s[4])+1):
                res.append(f"{chr(col)}{row}")
        return res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 class Solution:
#       2     def cellsInRange(self, s: str) -> List[str]:
#       3         res = []
#
# Cell In[16], line 2, in Solution()
#       1 class Solution:
# ----> 2     def cellsInRange(self, s: str) -> List[str]:
#       3         res = []
#       4         for col in range(ord(s[0]),ord(s[3])+1):
#
# NameError: name 'List' is not defined
